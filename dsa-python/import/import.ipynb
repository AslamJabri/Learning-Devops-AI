# %%
#Importing Modules in Python

# %% [markdown]
# # Importing Modules in Python
# In Python , modules and packages help organise and reuse code. Here's comprehensive guide on how to import them.

# %%
import math
math.sqrt(8)
