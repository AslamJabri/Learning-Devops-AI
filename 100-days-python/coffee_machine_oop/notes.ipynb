# %% [markdown]
# # OOPS
#
# Object is created by two things it can have things and it can do things- Attributes and methods. In other words a piece of data and what can you do with that data.
#     Attributes are nothing but a variable
#     methods are nothing but a functions
#     Note: These are tightly coupled with an object
#
# With this coupled thing called object we can create as many object as we want. That blueprint is called a class
#
# creating object from class
#
# objectname = className
# car = CarBlueprint()

# %%
from turtle import Turtle

timmy = Turtle()
print(timmy)
