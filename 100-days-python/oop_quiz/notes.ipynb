# %% [markdown]
# Class is a Blueprint. But gow do we create our own class.
# ##SYNTAX
#     The naming convention in class is the first letter of everyword should be captilized. <PascalCase>
#     class User:
#         #<everything here should be indented>
#         pass
#
# How to initilize the object from a class
# user_1 = User()
#
# ## An attribute is a variable that is associated with an object.
#
# Once creating the class we need a constructor it is a special, built in method inside a class that automatically runs the exact moment you create a new object from that blueprint.
# It is like a initial setup.

# %%
class User:
    # This is a Constructor
    def __init__(self,user_id,username):
        self.id = user_id
        self.username = username
